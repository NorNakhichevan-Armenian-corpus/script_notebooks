# %% [markdown]
# ### Data

# %%
import pandas as pd

# %%
df = pd.read_pickle('data2.pkl')
df
# Out:
#                   title                                               text  \
# 0         ԴՊՐՈՑԻ ՃԱՆՓԱՆ  ԴՊՐՈՑԻ ՃԱՆՓԱՆ \n(Թոփտիի խոսվածքով) \n\nԲուզլավ...
# 1          ՄԵՐ «ԸՆԿԵՐԸ»  ՄԵՐ «ԸՆԿԵՐԸ» \n\nԴասարանին դուռը բացվեցավ, Երկ...
# 2    ՄԵՐ ԽԱՄՈՒԹԻ ՃԱՆՓԱՆ  ՄԵՐ ԽԱՄՈՒԹԻ ՃԱՆՓԱՆ \n(Թոփտիի խոսվածքով) \n\nՄե...
# 3                ՄԱՇԻՆԸ  ՄԱՇԻՆԸ \n\nԳասպար, Խաթուն միասին, Քաղաք էշտալ ...
# 4     ԹՈՓՏԻՆ ԵՎ ԹՈՓՑԻԿԸ  ԹՈՓՏԻՆ ԵՎ ԹՈՓՑԻԿԸ \n\nԻնչքան տարուք դուն կառնո...
# ..                  ...                                                ...
# 163     ԵՐԳ ՔԵՖԵԻ ՄԱՍԻՆ  ԵՐԳ ՔԵՖԵԻ ՄԱՍԻՆ\n\nՔէֆէ քաղաք, բայձառ քաղաք, \...
# 164         ՍԱՆԴՌԻ ԵՐԳԸ  ՍԱՆԴՌԻ ԵՐԳԸ\n\nՀէնդէք ընգա, սանդըռ կըդա, \nՍան...
# 165      ԳԱՐՋՈՒԳ ՄԱՌՏԻՆ  ԳԱՐՋՈՒԳ ՄԱՌՏԻՆ\n\nՀէ՜յ, մէգդի գացէք մէյդան, \n...
# 166               ՑԱՓԷԹ  ՑԱՓԷԹ\n\nԿըլլայի – տա ան ատէնը էռսուն-էռսունհի...
# 167     Մեր հարսնիքները  Մեր հարսնիքները\nՄեկ քանի օրմ սիկից առչով կանչ...
#
#      date          source    genre  tokens_number  \
# 0    1968  Atamanyan_2006     poem             83
# 1    1999  Atamanyan_2006     poem             66
# 2    1971  Atamanyan_2006     poem             93
# 3    1971  Atamanyan_2006     poem             98
# 4    1973  Atamanyan_2006     poem            153
# ..    ...             ...      ...            ...
# 163        Dagldiyan_2023  unknown             69
# 164        Dagldiyan_2023  unknown             65
# 165        Dagldiyan_2023  unknown            150
# 166        Dagldiyan_2023  unknown            482
# 167        Dagldiyan_2023  unknown            487
#
#                                           preprocessed  \
# 0    [դպրոցի, ճանփան, թոփտիի, խոսվածքով, բուզլավուխ...
# 1    [մեր, ընկերը, դասարանին, դուռը, բացվեցավ, երկո...
# 2    [մեր, խամութի, ճանփան, թոփտիի, խոսվածքով, մեր,...
# 3    [մաշինը, գասպար, խաթուն, միասին, քաղաք, էշտալ,...
# 4    [թոփտին, եվ, թոփցիկը, ինչքան, տարուք, դուն, կա...
# ..                                                 ...
# 163  [երգ, քեֆեի, մասին, քէֆէ, քաղաք, բայձառ, քաղաք...
# 164  [սանդռի, երգը, հէնդէք, ընգա, սանդըռ, կըդա, սան...
# 165  [գարջուգ, մառտին, հէյ, մէգդի, գացէք, մէյդան, ի...
# 166  [ցափէթ, կըլլայի, –, տա, ան, ատէնը, էռսուն-էռսո...
# 167  [մեր, հարսնիքները, մեկ, քանի, օրմ, սիկից, առչո...
#
#                                            analyses_EA  count_EA  \
# 0    [[{'wf': 'դպրոցի', 'lemma': 'դպրոց', 'gramm': ...        46
# 1    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...        57
# 2    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...        62
# 3    [[{'wf': 'մաշինը', 'lemma': 'մաշ', 'gramm': ['...        67
# 4    [[{'wf': 'թոփտին', 'lemma': '', 'gramm': [], '...       128
# ..                                                 ...       ...
# 163  [[{'wf': 'երգ', 'lemma': 'երգ', 'gramm': ['N',...        24
# 164  [[{'wf': 'սանդռի', 'lemma': '', 'gramm': [], '...        38
# 165  [[{'wf': 'գարջուգ', 'lemma': '', 'gramm': [], ...        59
# 166  [[{'wf': 'ցափէթ', 'lemma': '', 'gramm': [], 'w...       253
# 167  [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...       403
#
#                                            analyses_WA  count_WA  \
# 0    [[{'wf': 'դպրոցի', 'lemma': 'դպրոց', 'gramm': ...        39
# 1    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...        61
# 2    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...        72
# 3    [[{'wf': 'մաշինը', 'lemma': 'մաշ', 'gramm': ['...        96
# 4    [[{'wf': 'թոփտին', 'lemma': '', 'gramm': [], '...       128
# ..                                                 ...       ...
# 163  [[{'wf': 'երգ', 'lemma': 'երգ', 'gramm': ['N',...        32
# 164  [[{'wf': 'սանդռի', 'lemma': '', 'gramm': [], '...        25
# 165  [[{'wf': 'գարջուգ', 'lemma': '', 'gramm': [], ...        69
# 166  [[{'wf': 'ցափէթ', 'lemma': '', 'gramm': [], 'w...       382
# 167  [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...       411
#
#                                           analyses_NNA  count_NNA  \
# 0    [[{'wf': 'դպրոցի', 'lemma': 'դպրոց', 'gramm': ...         46
# 1    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...         67
# 2    [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...         62
# 3    [[{'wf': 'մաշինը', 'lemma': 'մաշ', 'gramm': ['...         88
# 4    [[{'wf': 'թոփտին', 'lemma': '', 'gramm': [], '...        130
# ..                                                 ...        ...
# 163  [[{'wf': 'երգ', 'lemma': 'երգ', 'gramm': ['N',...         65
# 164  [[{'wf': 'սանդռի', 'lemma': '', 'gramm': [], '...         60
# 165  [[{'wf': 'գարջուգ', 'lemma': 'գարջուգ', 'gramm...        149
# 166  [[{'wf': 'ցափէթ', 'lemma': '', 'gramm': [], 'w...        447
# 167  [[{'wf': 'մեր', 'lemma': 'մենք', 'gramm': ['PR...        514
#
#      total_count_EA  total_count_WA  total_count_NNA
# 0                54              53               66
# 1                91             139              127
# 2                96             136              102
# 3                99             230              200
# 4               244             214              210
# ..              ...             ...              ...
# 163              38              42              113
# 164             108              39              130
# 165              77             125              367
# 166             437             828             1163
# 167             765             801             1150
#
# [168 rows x 16 columns]

# %% [markdown]
# ### Get token counts for Nor-Nakhichevan texts

# %%
from collections import Counter
from itertools import chain
from pprint import pprint

# %%
def get_token_counts(preprocessed_text):
    return Counter(chain.from_iterable(preprocessed_text))

# %%
token_counts = get_token_counts(df['preprocessed'])
print(len(token_counts) - 2)
print()
pprint([i for i in token_counts.most_common(300) if i[0] != '' and i[0] != '–'])
# Out:
# 22193
#
# [('ալ', 3081),
#  ('է', 1897),
#  ('մեկ', 914),
#  ('ինչ', 894),
#  ('ասաց', 764),
#  ('իդա', 747),
#  ('էր', 744),
#  ('որ', 650),
#  ('ես', 632),
#  ('ադ', 610),
#  ('պիտ', 518),
#  ('և', 476),
#  ('մեր', 463),
#  ('նը', 454),
#  ('շտե', 423),
#  ('կը', 372),
#  ('չէ', 364),
#  ('մեչը', 354),
#  ('բան', 344),
#  ('հատ', 335),
#  ('վրան', 309),
#  ('համար', 296),
#  ('ադպես', 295),
#  ('ին', 285),
#  ('սա', 269),
#  ('կասե', 265),
#  ('ան', 263),
#  ('համա', 260),
#  ('էղավ', 254),
#  ('տունը', 251),
#  ('ինձի', 249),
#  ('հետ', 244),
#  ('կենե', 233),
#  ('մեմը', 230),
#  ('ըռինդ', 223),
#  ('պան', 221),
#  ('խաթի', 218),
#  ('ինչես', 217),
#  ('պետք', 215),
#  ('իմ', 213),
#  ('աս', 211),
#  ('դըհա', 211),
#  ('նարա', 209),
#  ('սաղ', 201),
#  ('մաշդը', 199),
#  ('մեծ', 194),
#  ('էղած', 192),
#  ('նա', 186),
#  ('մաշդ', 183),
#  ('քեզի', 181),
#  ('հանա', 177),
#  ('ասի', 177),
#  ('էյ', 173),
#  ('դուն', 171),
#  ('չի', 164),
#  ('քանի', 162),
#  ('ինքն', 162),
#  ('իրեն', 160),
#  ('էին', 160),
#  ('մեմ', 160),
#  ('դա', 159),
#  ('հայդը', 154),
#  ('էլլավ', 153),
#  ('էկավ', 153),
#  ('չիմ', 152),
#  ('ախռ', 152),
#  ('տղան', 151),
#  ('հիչ', 151),
#  ('ու', 150),
#  ('էրկու', 147),
#  ('բանը', 146),
#  ('պես', 144),
#  ('թող', 142),
#  ('արավ', 138),
#  ('մինք', 136),
#  ('ժամանակ', 135),
#  ('նես', 133),
#  ('օր', 131),
#  ('դհա', 130),
#  ('անելու', 130),
#  ('խիստ', 128),
#  ('տեղ', 127),
#  ('ըլա', 126),
#  ('օրը', 124),
#  ('տեղը', 124),
#  ('բաշլայից', 124),
#  ('մասին', 124),
#  ('չիտիմ', 123),
#  ('կա', 122),
#  ('չէր', 121),
#  ('կըլա', 118),
#  ('շինըխ', 115),
#  ('ձո', 115),
#  ('մաշդուն', 114),
#  ('դեյին', 114),
#  ('շինը', 114),
#  ('չին', 112),
#  ('մեքատ', 111),
#  ('էկած', 110),
#  ('ժեք', 110),
#  ('իրենց', 109),
#  ('ադիվոր', 108),
#  ('չիքա', 108),
#  ('հա', 107),
#  ('բիդ', 106),
#  ('յոնոմիշ', 105),
#  ('ալղը', 103),
#  ('յալ', 102),
#  ('տուն', 101),
#  ('շատ', 101),
#  ('ուրիշ', 101),
#  ('արած', 100),
#  ('գենե', 100),
#  ('կընայիս', 98),
#  ('իմիս', 98),
#  ('ինա', 98),
#  ('ով', 97),
#  ('քովը', 95),
#  ('ինչի', 95),
#  ('ամեն', 93),
#  ('զայեր', 93),
#  ('թ', 92),
#  ('կայնած', 90),
#  ('նացա', 90),
#  ('պանը', 88),
#  ('տղին', 88),
#  ('էտեվ', 88),
#  ('մի', 87),
#  ('նոմայ', 86),
#  ('քիչ', 86),
#  ('էի', 86),
#  ('կասիմ', 85),
#  ('հարցուց', 85),
#  ('էղածը', 84),
#  ('աղան', 83),
#  ('հաբա', 81),
#  ('կամ', 80),
#  ('տուվից', 79),
#  ('կնիկը', 79),
#  ('դեպի', 78),
#  ('մեկը', 78),
#  ('մեն', 78),
#  ('կանե', 78),
#  ('վերչը', 77),
#  ('առավ', 77),
#  ('ասպես', 76),
#  ('կասին', 76),
#  ('ասին', 76),
#  ('մեչ', 75),
#  ('ալայ', 74),
#  ('անկից', 72),
#  ('նոր', 71),
#  ('միտք', 70),
#  ('ինքը', 70),
#  ('իդապես', 70),
#  ('նայե', 69),
#  ('իս', 68),
#  ('գնաց', 68),
#  ('անգամ', 68),
#  ('մեձա', 68),
#  ('մեմեծկի', 67),
#  ('նստած', 67),
#  ('մեկալ', 67),
#  ('ջորով', 66),
#  ('անցավ', 66),
#  ('տեղեն', 66),
#  ('էղիլ', 66),
#  ('վրա', 65),
#  ('բաբին', 65),
#  ('որը', 65),
#  ('հադ', 65),
#  ('բաշլայեցին', 64),
#  ('տըղան', 63),
#  ('խայրով', 63),
#  ('վրայեն', 63),
#  ('կանին', 62),
#  ('նորեն', 62),
#  ('էկան', 62),
#  ('աղային', 62),
#  ('արին', 61),
#  ('արա', 61),
#  ('անել', 61),
#  ('դեյեն', 61),
#  ('աղա', 60),
#  ('ժամանակը', 60),
#  ('նաքա', 59),
#  ('մեզի', 59),
#  ('մինչև', 59),
#  ('չենե', 59),
#  ('էլ', 59),
#  ('հարցուցի', 59),
#  ('ադիվուկը', 58),
#  ('երբ', 58),
#  ('տունին', 58),
#  ('տակը', 58),
#  ('անունը', 58),
#  ('կելլե', 58),
#  ('քուքա', 57),
#  ('բայց', 57),
#  ('տեսոք', 57),
#  ('աշտըխ', 56),
#  ('գալաջի', 56),
#  ('ըլալու', 56),
#  ('դուս', 56),
#  ('բաներ', 56),
#  ('վար', 56),
#  ('անպես', 55),
#  ('էտև', 55),
#  ('անիմ', 55),
#  ('համան', 54),
#  ('մաշդու', 54),
#  ('որին', 54),
#  ('վերչացավ', 54),
#  ('հանից', 53),
#  ('ասա', 53),
#  ('ախչիկանը', 53),
#  ('յաշ', 52),
#  ('գլոխը', 52),
#  ('այդ', 52),
#  ('մեգ', 52),
#  ('գեղի', 51),
#  ('ընկավ', 51),
#  ('ման', 51),
#  ('արինք', 51),
#  ('հոն', 51),
#  ('կնայիս', 51),
#  ('ավելի', 51),
#  ('վըրան', 51),
#  ('մութ', 50),
#  ('տալու', 50),
#  ('մաշդիք', 50),
#  ('տա', 50),
#  ('միշտ', 49),
#  ('չորս', 49),
#  ('մաշինը', 49),
#  ('գոյա', 49),
#  ('այս', 49),
#  ('հարսնիք', 49),
#  ('չիս', 49),
#  ('առաչվան', 49),
#  ('էղա', 48),
#  ('ասած', 48),
#  ('անքան', 48),
#  ('մը', 48),
#  ('արի', 48),
#  ('ասլան', 48),
#  ('են', 47),
#  ('էլլած', 47),
#  ('պատիվ', 47),
#  ('փոքր', 47),
#  ('պատմելու', 47),
#  ('կնկանը', 47),
#  ('անելեն', 47),
#  ('էինք', 47),
#  ('էլլա', 46),
#  ('կընաց', 46),
#  ('կընայիմ', 46),
#  ('մեչեն', 46),
#  ('նայինք', 46),
#  ('օշտախ', 46),
#  ('թագավորին', 46),
#  ('տարի', 45),
#  ('կան', 45),
#  ('բանին', 45),
#  ('էկիլ', 45),
#  ('մեչն', 44),
#  ('թոփ', 43),
#  ('սաշինը', 43),
#  ('ջուր', 43),
#  ('այն', 43),
#  ('կեշտա', 43),
#  ('էլլան', 43),
#  ('ըլար', 43),
#  ('էրկան', 43),
#  ('որպեսզի', 43),
#  ('ասօր', 42),
#  ('թոփտի', 42),
#  ('քեֆ', 42),
#  ('ձեր', 42),
#  ('շիտակ', 42),
#  ('արիլ', 42),
#  ('բռնած', 42),
#  ('սյա', 42),
#  ('ձիյին', 42),
#  ('ա', 42),
#  ('մեքադ', 42),
#  ('սաբախտան', 41),
#  ('ձեզի', 41),
#  ('քենը', 41),
#  ('բաբիյին', 41),
#  ('ախպար', 41),
#  ('էդև', 41),
#  ('սուրեն', 41),
#  ('թիլքին', 41),
#  ('առի', 41),
#  ('առանց', 40),
#  ('վայ', 40),
#  ('ասելու', 40)]

# %% [markdown]
# Write token counts to file

# %%
with open('NNA_corpus_wordlist.tsv', 'w', encoding='utf8') as f:
    for i in [i for i in token_counts.most_common() \
              if i[0] != '' and i[0] != '–']:
        f.write(i[0] + '\t' + str(i[1]) + '\n')

# %%
df = pd.read_csv('NNA_corpus_wordlist.tsv', sep='\t', \
                 header=None, names=['token', 'count'])
df.head(3)
# Out:
#   token  count
# 0    ալ   3081
# 1     է   1897
# 2   մեկ    914

# %%
print(len(df['count'].value_counts()))
df['count'].value_counts().head(20)
# Out:
# 185
# count
# 1     13702
# 2      3283
# 3      1429
# 4       825
# 5       521
# 6       343
# 7       299
# 8       196
# 9       168
# 10      138
# 11      108
# 12       97
# 13       85
# 14       72
# 15       64
# 16       54
# 17       47
# 19       43
# 18       39
# 20       33
# Name: count, dtype: int64

# %%
df['count'].value_counts().hist(bins=len(df['count'].value_counts()))
# Out:
# <Axes: >

# %% [markdown]
# ### Get word per million (WPM) for NNA tokens

# %%
text_size = 102592
token_wpm = sorted({
    k: round(v / text_size * 1000000) for k, v in token_counts.items() \
    if k != '' and k != '–'}.items(), key=lambda x: x[1], reverse=True)
print()
pprint(token_wpm[:300])
# Out:
# [('ալ', 30032),
#  ('է', 18491),
#  ('մեկ', 8909),
#  ('ինչ', 8714),
#  ('ասաց', 7447),
#  ('իդա', 7281),
#  ('էր', 7252),
#  ('որ', 6336),
#  ('ես', 6160),
#  ('ադ', 5946),
#  ('պիտ', 5049),
#  ('և', 4640),
#  ('մեր', 4513),
#  ('նը', 4425),
#  ('շտե', 4123),
#  ('կը', 3626),
#  ('չէ', 3548),
#  ('մեչը', 3451),
#  ('բան', 3353),
#  ('հատ', 3265),
#  ('վրան', 3012),
#  ('համար', 2885),
#  ('ադպես', 2875),
#  ('ին', 2778),
#  ('սա', 2622),
#  ('կասե', 2583),
#  ('ան', 2564),
#  ('համա', 2534),
#  ('էղավ', 2476),
#  ('տունը', 2447),
#  ('ինձի', 2427),
#  ('հետ', 2378),
#  ('կենե', 2271),
#  ('մեմը', 2242),
#  ('ըռինդ', 2174),
#  ('պան', 2154),
#  ('խաթի', 2125),
#  ('ինչես', 2115),
#  ('պետք', 2096),
#  ('իմ', 2076),
#  ('աս', 2057),
#  ('դըհա', 2057),
#  ('նարա', 2037),
#  ('սաղ', 1959),
#  ('մաշդը', 1940),
#  ('մեծ', 1891),
#  ('էղած', 1871),
#  ('նա', 1813),
#  ('մաշդ', 1784),
#  ('քեզի', 1764),
#  ('հանա', 1725),
#  ('ասի', 1725),
#  ('էյ', 1686),
#  ('դուն', 1667),
#  ('չի', 1599),
#  ('քանի', 1579),
#  ('ինքն', 1579),
#  ('իրեն', 1560),
#  ('էին', 1560),
#  ('մեմ', 1560),
#  ('դա', 1550),
#  ('հայդը', 1501),
#  ('էլլավ', 1491),
#  ('էկավ', 1491),
#  ('չիմ', 1482),
#  ('ախռ', 1482),
#  ('տղան', 1472),
#  ('հիչ', 1472),
#  ('ու', 1462),
#  ('էրկու', 1433),
#  ('բանը', 1423),
#  ('պես', 1404),
#  ('թող', 1384),
#  ('արավ', 1345),
#  ('մինք', 1326),
#  ('ժամանակ', 1316),
#  ('նես', 1296),
#  ('օր', 1277),
#  ('դհա', 1267),
#  ('անելու', 1267),
#  ('խիստ', 1248),
#  ('տեղ', 1238),
#  ('ըլա', 1228),
#  ('օրը', 1209),
#  ('տեղը', 1209),
#  ('բաշլայից', 1209),
#  ('մասին', 1209),
#  ('չիտիմ', 1199),
#  ('կա', 1189),
#  ('չէր', 1179),
#  ('կըլա', 1150),
#  ('շինըխ', 1121),
#  ('ձո', 1121),
#  ('մաշդուն', 1111),
#  ('դեյին', 1111),
#  ('շինը', 1111),
#  ('չին', 1092),
#  ('մեքատ', 1082),
#  ('էկած', 1072),
#  ('ժեք', 1072),
#  ('իրենց', 1062),
#  ('ադիվոր', 1053),
#  ('չիքա', 1053),
#  ('հա', 1043),
#  ('բիդ', 1033),
#  ('յոնոմիշ', 1023),
#  ('ալղը', 1004),
#  ('յալ', 994),
#  ('տուն', 984),
#  ('շատ', 984),
#  ('ուրիշ', 984),
#  ('արած', 975),
#  ('գենե', 975),
#  ('կընայիս', 955),
#  ('իմիս', 955),
#  ('ինա', 955),
#  ('ով', 945),
#  ('քովը', 926),
#  ('ինչի', 926),
#  ('ամեն', 907),
#  ('զայեր', 907),
#  ('թ', 897),
#  ('կայնած', 877),
#  ('նացա', 877),
#  ('պանը', 858),
#  ('տղին', 858),
#  ('էտեվ', 858),
#  ('մի', 848),
#  ('նոմայ', 838),
#  ('քիչ', 838),
#  ('էի', 838),
#  ('կասիմ', 829),
#  ('հարցուց', 829),
#  ('էղածը', 819),
#  ('աղան', 809),
#  ('հաբա', 790),
#  ('կամ', 780),
#  ('տուվից', 770),
#  ('կնիկը', 770),
#  ('դեպի', 760),
#  ('մեկը', 760),
#  ('մեն', 760),
#  ('կանե', 760),
#  ('վերչը', 751),
#  ('առավ', 751),
#  ('ասպես', 741),
#  ('կասին', 741),
#  ('ասին', 741),
#  ('մեչ', 731),
#  ('ալայ', 721),
#  ('անկից', 702),
#  ('նոր', 692),
#  ('միտք', 682),
#  ('ինքը', 682),
#  ('իդապես', 682),
#  ('նայե', 673),
#  ('իս', 663),
#  ('գնաց', 663),
#  ('անգամ', 663),
#  ('մեձա', 663),
#  ('մեմեծկի', 653),
#  ('նստած', 653),
#  ('մեկալ', 653),
#  ('ջորով', 643),
#  ('անցավ', 643),
#  ('տեղեն', 643),
#  ('էղիլ', 643),
#  ('վրա', 634),
#  ('բաբին', 634),
#  ('որը', 634),
#  ('հադ', 634),
#  ('բաշլայեցին', 624),
#  ('տըղան', 614),
#  ('խայրով', 614),
#  ('վրայեն', 614),
#  ('կանին', 604),
#  ('նորեն', 604),
#  ('էկան', 604),
#  ('աղային', 604),
#  ('արին', 595),
#  ('արա', 595),
#  ('անել', 595),
#  ('դեյեն', 595),
#  ('աղա', 585),
#  ('ժամանակը', 585),
#  ('նաքա', 575),
#  ('մեզի', 575),
#  ('մինչև', 575),
#  ('չենե', 575),
#  ('էլ', 575),
#  ('հարցուցի', 575),
#  ('ադիվուկը', 565),
#  ('երբ', 565),
#  ('տունին', 565),
#  ('տակը', 565),
#  ('անունը', 565),
#  ('կելլե', 565),
#  ('քուքա', 556),
#  ('բայց', 556),
#  ('տեսոք', 556),
#  ('աշտըխ', 546),
#  ('գալաջի', 546),
#  ('ըլալու', 546),
#  ('դուս', 546),
#  ('բաներ', 546),
#  ('վար', 546),
#  ('անպես', 536),
#  ('էտև', 536),
#  ('անիմ', 536),
#  ('համան', 526),
#  ('մաշդու', 526),
#  ('որին', 526),
#  ('վերչացավ', 526),
#  ('հանից', 517),
#  ('ասա', 517),
#  ('ախչիկանը', 517),
#  ('յաշ', 507),
#  ('գլոխը', 507),
#  ('այդ', 507),
#  ('մեգ', 507),
#  ('գեղի', 497),
#  ('ընկավ', 497),
#  ('ման', 497),
#  ('արինք', 497),
#  ('հոն', 497),
#  ('կնայիս', 497),
#  ('ավելի', 497),
#  ('վըրան', 497),
#  ('մութ', 487),
#  ('տալու', 487),
#  ('մաշդիք', 487),
#  ('տա', 487),
#  ('միշտ', 478),
#  ('չորս', 478),
#  ('մաշինը', 478),
#  ('գոյա', 478),
#  ('այս', 478),
#  ('հարսնիք', 478),
#  ('չիս', 478),
#  ('առաչվան', 478),
#  ('էղա', 468),
#  ('ասած', 468),
#  ('անքան', 468),
#  ('մը', 468),
#  ('արի', 468),
#  ('ասլան', 468),
#  ('են', 458),
#  ('էլլած', 458),
#  ('պատիվ', 458),
#  ('փոքր', 458),
#  ('պատմելու', 458),
#  ('կնկանը', 458),
#  ('անելեն', 458),
#  ('էինք', 458),
#  ('էլլա', 448),
#  ('կընաց', 448),
#  ('կընայիմ', 448),
#  ('մեչեն', 448),
#  ('նայինք', 448),
#  ('օշտախ', 448),
#  ('թագավորին', 448),
#  ('տարի', 439),
#  ('կան', 439),
#  ('բանին', 439),
#  ('էկիլ', 439),
#  ('մեչն', 429),
#  ('թոփ', 419),
#  ('սաշինը', 419),
#  ('ջուր', 419),
#  ('այն', 419),
#  ('կեշտա', 419),
#  ('էլլան', 419),
#  ('ըլար', 419),
#  ('էրկան', 419),
#  ('որպեսզի', 419),
#  ('ասօր', 409),
#  ('թոփտի', 409),
#  ('քեֆ', 409),
#  ('ձեր', 409),
#  ('շիտակ', 409),
#  ('արիլ', 409),
#  ('բռնած', 409),
#  ('սյա', 409),
#  ('ձիյին', 409),
#  ('ա', 409),
#  ('մեքադ', 409),
#  ('սաբախտան', 400),
#  ('ձեզի', 400),
#  ('քենը', 400),
#  ('բաբիյին', 400),
#  ('ախպար', 400),
#  ('էդև', 400),
#  ('սուրեն', 400),
#  ('թիլքին', 400),
#  ('առի', 400),
#  ('առանց', 390),
#  ('վայ', 390),
#  ('ասելու', 390),
#  ('ախչիկը', 390),
#  ('մեմա', 390)]

# %% [markdown]
# ### Load EANC 300 frequent tokens list

# %% [markdown]
# Here we will use the list retreived from EANC website (http://eanc.net/EANC/stat/statistics.php?interface_language=en). It is in some respects different from the list available at the updated EANC parser repository (https://github.com/timarkh/uniparser-grammar-eastern-armenian/blob/master/wordlists/eanc_wordlist.csv), see below

# %%
# !wget 'https://github.com/timarkh/uniparser-grammar-eastern-armenian/raw/refs/heads/master/wordlists/eanc_wordlist.csv'
# Out:
# --2026-06-17 14:18:48--  https://github.com/timarkh/uniparser-grammar-eastern-armenian/raw/refs/heads/master/wordlists/eanc_wordlist.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/timarkh/uniparser-grammar-eastern-armenian/refs/heads/master/wordlists/eanc_wordlist.csv [following]
# --2026-06-17 14:18:48--  https://raw.githubusercontent.com/timarkh/uniparser-grammar-eastern-armenian/refs/heads/master/wordlists/eanc_wordlist.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31749037 (30M) [application/octet-stream]
# Saving to: ‘eanc_wordlist.csv.1’
#
# eanc_wordlist.csv.1 100%[===================>]  30.28M   180MB/s    in 0.2s
#
# 2026-06-17 14:18:49 (180 MB/s) - ‘eanc_wordlist.csv.1’ saved [31749037/31749037]

# %%
with open('eanc_wordlist.csv', 'r', encoding='utf8') as f:
    EANC_wordlist_300 = f.readlines(300)
EANC_wordlist_300 = [tuple(i.strip('\n').split('\t')) for i in EANC_wordlist_300]
print(EANC_wordlist_300[:10])
# Out:
# [('է', '2991585'), ('որ', '1258415'), ('էր', '1099222'), ('և', '1049054'), ('են', '1032197'), ('ու', '927497'), ('մի', '762815'), ('եւ', '694042'), ('ես', '578388'), ('էլ', '508779')]

# %%
EA_ranked_300 = '''է
եվ
որ
են
էր
ու
մի
ես
այդ
էլ
իր
թե
համար
նա
եմ
էին
այն
այս
ինչ
հետ
ոչ
բայց
իսկ
նրա
մեր
մեջ
չի
վրա
նաեվ
մասին
շատ
ա
ինչպես
կարող
երբ
հետո
կամ
իմ
ավելի
միայն
չէ
ինձ
ի
եթե
պետք
մեծ
իրենց
նրան
այլ
ենք
մենք
նրանց
քանի
ասաց
նոր
անգամ
ժամանակ
ամեն
որը
դա
բոլոր
մոտ
չէր
երկու
արդեն
մինչեվ
առաջին
չեն
լավ
1
առաջ
բան
ասում
դու
սակայն
2
մեկ
որոնք
հայ
դուրս
նրանք
հայաստանի
նման
չեմ
պիտի
եք
մեզ
ուզում
ըստ
քեզ
եղել
ապա
հիմա
կողմից
որի
ունի
տարի
դեռ
3
ձեր
քո
էի
ե
տալիս
իրեն
դուք
որպես
թ
ով
ինչու
հենց
կ
առանց
դեպի
մ
քաղաքական
որովհետեվ
տակ
դեմ
հ
մեկը
այստեղ
քիչ
կարելի
դեպքում
այսօր
գալիս
մարդ
օր
վերջին
կա
ասել
հհ
ամբողջ
նույն
ինքը
լինի
ձեզ
կը
որեվէ
այնպես
սա
տեղի
ազգային
ընթացքում
ուր
ս
նախագահ
հայկական
այնքան
դրա
պետական
4
մարդիկ
այժմ
ահա
երեկ
որտեղ
մյուս
եվս
քան
այդպես
միշտ
օրը
անում
գնում
ճիշտ
բարձր
տեղ
պես
նույնիսկ
ուրիշ
հա
երեք
տ
չկա
հազար
ինչ-որ
նորից
երկրի
նկատմամբ
գ
մարդկանց
վեր
միջազգային
այնտեղ
որոնց
այո
դ
տարբեր
մէջ
եկել
մարդու
թող
որն
թվում
հայաստանում
ոչինչ
ն
էս
ցույց
երկար
դրանք
կան
մը
երկրորդ
5
կարծես
էդ
10
վ
տեսնում
ինքն
փոքր
այսպես
տեր
որպեսզի
նայում
հայոց
հայտնի
պատճառով
գլխավոր
լ
լինում
տուն
ընդհանուր
եկավ
6
տարվա
կլինի
սովետական
ռ
դրամ
որոշ
լինել
ուրեմն
այսինքն
կարծում
ժողովրդի
օրինակ
որքան
բացի
ժամը
բաց
իրար
դե
աշխատանքի
աշխարհի
իհարկե
անհրաժեշտ
կարեվոր
չես
ում
թույլ
խոսում
միջեվ
հին
հնարավոր
տվեց
կյանքի
տալ
էինք
հանրապետության
դրանց
երեվանի
էլի
ունեն
ձեռք
ը
նույնպես
կուսակցության
հանկարծ
գործում
տվել
7
0
սիրում
ետ
այնպիսի
հիմնական
այլեվս
նախագահի
ծանր
հասարակական
պարզ
էն
հարցը
ունեցել
չենք
մասը
վերաբերյալ
ին
բոլորը
չէին
20
լինելու
այդպիսի
ազատ
չունի
8'''.split('\n')
print(len(EA_ranked_300))
# Out:
# 300

# %% [markdown]
# ### 300-token lists intersection: NNA and EA

# %%
set1 = set([i[0] for i in token_wpm[:300]])
set2 = set([i for i in EA_ranked_300])

# %%
print(len(set1.intersection(set2)))
pprint(set1.intersection(set2))
# Out:
# 72
# {'ա',
#  'ամեն',
#  'այդ',
#  'այն',
#  'այս',
#  'անգամ',
#  'առանց',
#  'ասաց',
#  'ավելի',
#  'բայց',
#  'բան',
#  'դա',
#  'դեպի',
#  'են',
#  'ես',
#  'երբ',
#  'է',
#  'էի',
#  'էին',
#  'էինք',
#  'էլ',
#  'էր',
#  'թ',
#  'թող',
#  'ժամանակ',
#  'իմ',
#  'ին',
#  'ինչ',
#  'ինքը',
#  'ինքն',
#  'իրեն',
#  'իրենց',
#  'կա',
#  'կամ',
#  'կան',
#  'կը',
#  'հա',
#  'համար',
#  'հետ',
#  'ձեր',
#  'մասին',
#  'մեծ',
#  'մեկ',
#  'մեկը',
#  'մեր',
#  'մը',
#  'մի',
#  'միշտ',
#  'նա',
#  'նոր',
#  'շատ',
#  'ով',
#  'որ',
#  'որը',
#  'որպեսզի',
#  'ու',
#  'ուրիշ',
#  'չէ',
#  'չէր',
#  'չի',
#  'պես',
#  'պետք',
#  'սա',
#  'վրա',
#  'տարի',
#  'տեղ',
#  'տուն',
#  'փոքր',
#  'քանի',
#  'քիչ',
#  'օր',
#  'օրը'}

# %% [markdown]
# ### 300-token lists difference: NNA and EA

# %%
print(len(set1.difference(set2)))
pprint(set1.difference(set2))
# Out:
# 228
# {'ադ',
#  'ադիվոր',
#  'ադիվուկը',
#  'ադպես',
#  'ալ',
#  'ալայ',
#  'ալղը',
#  'ախչիկանը',
#  'ախչիկը',
#  'ախպար',
#  'ախռ',
#  'աղա',
#  'աղային',
#  'աղան',
#  'ան',
#  'անել',
#  'անելեն',
#  'անելու',
#  'անիմ',
#  'անկից',
#  'անունը',
#  'անպես',
#  'անցավ',
#  'անքան',
#  'աշտըխ',
#  'առաչվան',
#  'առավ',
#  'առի',
#  'աս',
#  'ասա',
#  'ասած',
#  'ասելու',
#  'ասի',
#  'ասին',
#  'ասլան',
#  'ասպես',
#  'ասօր',
#  'արա',
#  'արած',
#  'արավ',
#  'արի',
#  'արիլ',
#  'արին',
#  'արինք',
#  'բաբիյին',
#  'բաբին',
#  'բաներ',
#  'բանը',
#  'բանին',
#  'բաշլայեցին',
#  'բաշլայից',
#  'բիդ',
#  'բռնած',
#  'գալաջի',
#  'գեղի',
#  'գենե',
#  'գլոխը',
#  'գնաց',
#  'գոյա',
#  'դեյեն',
#  'դեյին',
#  'դըհա',
#  'դհա',
#  'դուն',
#  'դուս',
#  'զայեր',
#  'էդև',
#  'էլլա',
#  'էլլած',
#  'էլլան',
#  'էլլավ',
#  'էկած',
#  'էկան',
#  'էկավ',
#  'էկիլ',
#  'էղա',
#  'էղած',
#  'էղածը',
#  'էղավ',
#  'էղիլ',
#  'էյ',
#  'էտեվ',
#  'էտև',
#  'էրկան',
#  'էրկու',
#  'ըլա',
#  'ըլալու',
#  'ըլար',
#  'ընկավ',
#  'ըռինդ',
#  'թագավորին',
#  'թիլքին',
#  'թոփ',
#  'թոփտի',
#  'ժամանակը',
#  'ժեք',
#  'իդա',
#  'իդապես',
#  'իմիս',
#  'ինա',
#  'ինձի',
#  'ինչես',
#  'ինչի',
#  'իս',
#  'խաթի',
#  'խայրով',
#  'խիստ',
#  'կայնած',
#  'կանե',
#  'կանին',
#  'կասե',
#  'կասիմ',
#  'կասին',
#  'կելլե',
#  'կենե',
#  'կեշտա',
#  'կըլա',
#  'կընայիմ',
#  'կընայիս',
#  'կընաց',
#  'կնայիս',
#  'կնիկը',
#  'կնկանը',
#  'հաբա',
#  'հադ',
#  'համա',
#  'համան',
#  'հայդը',
#  'հանա',
#  'հանից',
#  'հատ',
#  'հարսնիք',
#  'հարցուց',
#  'հարցուցի',
#  'հիչ',
#  'հոն',
#  'ձեզի',
#  'ձիյին',
#  'ձո',
#  'ման',
#  'մաշդ',
#  'մաշդը',
#  'մաշդիք',
#  'մաշդու',
#  'մաշդուն',
#  'մաշինը',
#  'մեգ',
#  'մեզի',
#  'մեկալ',
#  'մեձա',
#  'մեմ',
#  'մեմա',
#  'մեմեծկի',
#  'մեմը',
#  'մեն',
#  'մեչ',
#  'մեչեն',
#  'մեչը',
#  'մեչն',
#  'մեքադ',
#  'մեքատ',
#  'մինչև',
#  'մինք',
#  'միտք',
#  'մութ',
#  'յալ',
#  'յաշ',
#  'յոնոմիշ',
#  'նայե',
#  'նայինք',
#  'նարա',
#  'նացա',
#  'նաքա',
#  'նես',
#  'նը',
#  'նոմայ',
#  'նորեն',
#  'նստած',
#  'շինը',
#  'շինըխ',
#  'շիտակ',
#  'շտե',
#  'որին',
#  'չենե',
#  'չիմ',
#  'չին',
#  'չիս',
#  'չիտիմ',
#  'չիքա',
#  'չորս',
#  'պան',
#  'պանը',
#  'պատիվ',
#  'պատմելու',
#  'պիտ',
#  'ջորով',
#  'ջուր',
#  'սաբախտան',
#  'սաղ',
#  'սաշինը',
#  'սյա',
#  'սուրեն',
#  'վայ',
#  'վար',
#  'վերչացավ',
#  'վերչը',
#  'վըրան',
#  'վրայեն',
#  'վրան',
#  'տա',
#  'տալու',
#  'տակը',
#  'տեղեն',
#  'տեղը',
#  'տեսոք',
#  'տըղան',
#  'տղան',
#  'տղին',
#  'տունը',
#  'տունին',
#  'տուվից',
#  'քեզի',
#  'քենը',
#  'քեֆ',
#  'քովը',
#  'քուքա',
#  'օշտախ',
#  'և'}
